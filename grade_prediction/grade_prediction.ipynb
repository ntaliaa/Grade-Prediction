# %% [markdown]
#  # The Data Set
#  # Attributes for  student-mat.csv (Math course)  dataset:
# 1 school - student's school (binary: "GP" - Gabriel Pereira or "MS" - Mousinho da Silveira)
#
# 2 sex - student's sex (binary: "F" - female or "M" - male)
#
# 3 age - student's age (numeric: from 15 to 22)
#
# 4 address - student's home address type (binary: "U" - urban or "R" - rural)
#
# 5 famsize - family size (binary: "LE3" - less or equal to 3 or "GT3" - greater than 3)
#
# 6 Pstatus - parent's cohabitation status (binary: "T" - living together or "A" - apart
#
# 7 Medu - mother's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 8 Fedu - father's education (numeric: 0 - none,  1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# 9 Mjob - mother's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 10 Fjob - father's job (nominal: "teacher", "health" care related, civil "services" (e.g. administrative or police), "at_home" or "other")
#
# 11 reason - reason to choose this school (nominal: close to "home", school "reputation", "course" preference or "other")
#
# 12 guardian - student's guardian (nominal: "mother", "father" or "other")
#
# 13 traveltime - home to school travel time (numeric: 1 - <15 min., 2 - 15 to 30 min., 3 - 30 min. to 1 hour, or 4 - >1 hour)
#
# 14 studytime - weekly study time (numeric: 1 - <2 hours, 2 - 2 to 5 hours, 3 - 5 to 10 hours, or 4 - >10 hours)
#
# 15 failures - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# 16 schoolsup - extra educational support (binary: yes or no)
#
# 17 famsup - family educational support (binary: yes or no)
#
# 18 paid - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# 19 activities - extra-curricular activities (binary: yes or no)
#
# 20 nursery - attended nursery school (binary: yes or no)
#
# 21 higher - wants to take higher education (binary: yes or no)
#
# 22 internet - Internet access at home (binary: yes or no)
#
# 23 romantic - with a romantic relationship (binary: yes or no)
#
# 24 famrel - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# 25 freetime - free time after school (numeric: from 1 - very low to 5 - very high)
#
# 26 goout - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# 27 Dalc - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 28 Walc - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# 29 health - current health status (numeric: from 1 - very bad to 5 - very good)
#
# 30 absences - number of school absences (numeric: from 0 to 93)
#
#
#
#
# # these grades are related with the course subject:
# 31 G1 - first period grade (numeric: from 0 to 20)
# 31 G2 - second period grade (numeric: from 0 to 20)
# 32 G3 - final grade (numeric: from 0 to 20, output target)

# %%
#First we proccesing our data
import pandas as pd
#import the data from the csv file
df = pd.read_csv("student-mat.csv")
df = pd.DataFrame(df)
#modify the colunms yes->1 and no->0, because all the algorithms in data mining we will use can proccess data in string format
#we must have integers or floats, in our case we have one hot encoding and 0 or 1 for the 'yes' or 'no' features
for i in range(0, 395):
    if df.loc[i, "sex"] == 'F':
        df.loc[i, "sex"] = 0
    else:
        df.loc[i, "sex"] = 1
    if df.loc[i, "school"] ==  'GP':
        df.loc[i, "school"] = 0
    else:
        df.loc[i, "school"] = 1
    if df.loc[i, "romantic"] == 'no':
        df.loc[i, "romantic"] = 0
    else:
        df.loc[i, "romantic"] = 1

    if df.loc[i, "schoolsup"] == 'no':
        df.loc[i, "schoolsup"] = 0
    else:
        df.loc[i, "schoolsup"] = 1
        
    if df.loc[i, "famsup"] == 'no':
        df.loc[i, "famsup"] = 0
    else:
        df.loc[i, "famsup"] = 1
        
    if df.loc[i, "activities"] == 'no':
        df.loc[i, "activities"] = 0
    else:
        df.loc[i, "activities"] = 1
        
    if df.loc[i, "nursery"] == 'no':
        df.loc[i, "nursery"] = 0
    else:
        df.loc[i, "nursery"] = 1
        
    if df.loc[i, "higher"] == 'no':
        df.loc[i, "higher"] = 0
    else:
        df.loc[i, "higher"] = 1
        
    if df.loc[i, "internet"] == 'no':
        df.loc[i, "internet"] = 0
    else:
        df.loc[i, "internet"] = 1
    if df.loc[i, "paid"] == 'no':
        df.loc[i, "paid"] = 0
    else:
        df.loc[i, "paid"] = 1
    if df.loc[i, "address"] == 'U':
        df.loc[i, "address"] = 0
    else:
        df.loc[i, "address"] = 1
    if df.loc[i, "famsize"] == 'GT3':
        df.loc[i, "famsize"] = 0
    else:
        df.loc[i, "famsize"] = 1
        
    if df.loc[i, "Pstatus"] == 'A':
        df.loc[i, "Pstatus"] = 0
    else:
        df.loc[i, "Pstatus"] = 1


#also one hot encoding at the colunms
df = df.drop(['guardian'], axis=1)
one_hot_encoded = pd.get_dummies(df, dtype=int, columns=['Fjob', 'Mjob','reason'])

print(one_hot_encoded)
df = one_hot_encoded
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu  traveltime  \
# 0        0   0   18       0       0       0     4     4           2
# 1        0   0   17       0       0       1     1     1           1
# 2        0   0   15       0       1       1     1     1           1
# 3        0   0   15       0       0       1     4     2           1
# 4        0   0   16       0       0       1     3     3           1
# ..     ...  ..  ...     ...     ...     ...   ...   ...         ...
# 390      1   1   20       0       1       0     2     2           1
# 391      1   1   17       0       1       1     3     1           2
# 392      1   1   21       1       0       1     1     1           1
# 393      1   1   18       1       1       1     3     2           3
# 394      1   1   19       0       1       1     1     1           1
#
#      studytime  ...  Fjob_teacher Mjob_at_home Mjob_health Mjob_other  \
# 0            2  ...             1            1           0          0
# ...

# %% [markdown]
#  ### Now we can drop some features beacause we have 45 colunms. We will see the correlation between the features.
#  ![](https://i.stack.imgur.com/kT1Vv.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
correlation_matrix = df.corr()

# Print correlation matrix

# Optionally, you can visualize the correlation matrix using a heatmap
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=False, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
#  ## The correletion matrix is very big and we can see clearly with naked eye what features are correlate each other, so we will use the following function:

# %%
def find_correlated_features(data, threshold):
    # Calculate the correlation matrix
    correlation_matrix = data.corr()

    # Find pairs of features with correlation coefficient >= threshold
    correlated_features = []
    for i in range(len(correlation_matrix.columns)):
        for j in range(i+1, len(correlation_matrix.columns)):
            if abs(correlation_matrix.iloc[i, j]) >= threshold:
                correlated_features.append((correlation_matrix.columns[i], correlation_matrix.columns[j], correlation_matrix.iloc[i, j]))

    return correlated_features


threshold = 0.6

# Find correlated features
correlated_features = find_correlated_features(df, threshold)

# Print correlated features
if correlated_features:
    print("Pairs of features with correlation coefficient >= {}: ".format(threshold))
    for feature_pair in correlated_features:
        print("Features:", feature_pair[0], "and", feature_pair[1], "with correlation coefficient:", feature_pair[2])
# Out:
# Pairs of features with correlation coefficient >= 0.6:
# Features: Medu and Fedu with correlation coefficient: 0.6234551120806472
# Features: Dalc and Walc with correlation coefficient: 0.6475442300180093
# Features: G1 and G2 with correlation coefficient: 0.852118066364806
# Features: G1 and G3 with correlation coefficient: 0.8014679320174145
# Features: G2 and G3 with correlation coefficient: 0.9048679892693002
# Features: Fjob_other and Fjob_services with correlation coefficient: -0.6902750643793221

# %% [markdown]
# ## Drop the guardian colunm because the guardian of the student is irrelevant, as for the other 4 features, we keep the median of the 2

# %%
#put the median of the  Medu and Fedu and Dalc and Walc
mean_Medu = df['Medu'].mean()
mean_Fedu = df['Fedu'].mean()

# Calculate the median
median = (mean_Medu + mean_Fedu) / 2

print("Median:", median)
df = df.drop(['Fedu'], axis=1)
df.rename(columns={'Medu': 'Parents_edu'}, inplace=True)

# Replace all values in the renamed column
df['Parents_edu'] = df['Parents_edu'].replace(median)



mean_Medu = df['Dalc'].mean()
mean_Fedu = df['Walc'].mean()

# Calculate the median
median = (mean_Medu + mean_Fedu) / 2

print("Median:", median)
df = df.drop(['Dalc'], axis=1)
df.rename(columns={'Walc': 'Dalc_Walc_median'}, inplace=True)

# Replace all values in the renamed column
df['Dalc_Walc_median'] = df['Dalc_Walc_median'].replace(median)
# Out:
# Median: 2.6354430379746834
# Median: 1.8860759493670887
# C:\Users\kater\AppData\Local\Temp\ipykernel_24388\3558617892.py:13: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['Parents_edu'] = df['Parents_edu'].replace(median)
# C:\Users\kater\AppData\Local\Temp\ipykernel_24388\3558617892.py:28: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['Dalc_Walc_median'] = df['Dalc_Walc_median'].replace(median)

# %%
#Df_1 has the data without the G1
#Df_2 has the data without the G2
#Df_3 has the data without the G1 and G2
#Df_4 has the data will G1 and G2
#one data for each model we will train


df_1 = df.drop(['G1'], axis=1)
df_2 = df.drop(['G2'], axis=1)
df_3 = df.drop(['G1','G2'], axis=1)
df_4 = df
#preper for binary classification
for i in range(0,395):
    if df_1.loc[i, "G3"] >= 10:
        df_1.loc[i, "G3"] = 1
    else:
        df_1.loc[i, "G3"] = 0

# %% [markdown]
# ## Spilt into train and test data

# %%
from sklearn import metrics  
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report,\
    confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier


features_1 = df_1.drop('G3',axis=1)

X_train_1, X_test_1,\
    y_train_1, y_test_1 = train_test_split(features_1,
                                       df_1['G3'], test_size=0.15,random_state=42)


features = df_2.drop('G3',axis=1)
 
df_feat = pd.DataFrame(features,
                       columns=df.columns[:-1])
X_train_2, X_test_2,\
    y_train_2, y_test_2 = train_test_split(features,
                                       df_1['G3'],
                                       test_size=0.15,random_state=42)

features = df_3.drop('G3',axis=1)
 

X_train_3, X_test_3,\
    y_train_3, y_test_3 = train_test_split(features,
                                       df_1['G3'],
                                       test_size=0.15,random_state=42)


features = df_4.drop('G3',axis=1)
 
X_train_4, X_test_4,\
    y_train_4, y_test_4 = train_test_split(features,
                                       df_1['G3'],
                                       test_size=0.15,random_state=42)

# %% [markdown]
#  ## Binary Classifiers
#  ### We need to have and train 4 models 2 with 39 features, 2 with 38 missing the G1 and G2, and 1 with 40 features that the G1 and G2 are not missing

# %%
from sklearn.naive_bayes import GaussianNB


# Train the model 39 features missing G1
model_1 = GaussianNB()
model_1.fit(X_train_1, y_train_1)
y_pred = model_1.predict(X_test_1)
print("SCORE 1:",metrics.accuracy_score(y_test_1, y_pred))
# Train the model 39 features missing G2

model_2 = GaussianNB()
model_2.fit(X_train_2, y_train_2)
y_pred = model_2.predict(X_test_2)
print("SCORE 2:",metrics.accuracy_score(y_test_2, y_pred))
# Train the model 38 features

model_3 = GaussianNB()
model_3.fit(X_train_3, y_train_3)
y_pred = model_3.predict(X_test_3)
print("SCORE 3:",metrics.accuracy_score(y_test_3, y_pred))

# Train the model 40 features
model_4 = GaussianNB()
model_4.fit(X_train_4, y_train_4)
y_pred = model_4.predict(X_test_4)
print("SCORE 4:",metrics.accuracy_score(y_test_4, y_pred))
# Out:
# SCORE 1: 0.8166666666666667
# SCORE 2: 0.7833333333333333
# SCORE 3: 0.75
# SCORE 4: 0.8833333333333333

# %%
from sklearn import metrics  
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report,\
    confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
# Train the model 39 features

clf_1 = RandomForestClassifier(n_estimators = 130,max_features=41,random_state=13)  
clf_1.fit(X_train_1, y_train_1)
y_pred = clf_1.predict(X_test_1)
print("ACCURACY OF THE MODEL RF 1:", metrics.accuracy_score(y_test_1, y_pred))
# Train the model 39 features

clf_2 = RandomForestClassifier(n_estimators = 130,max_features=41,random_state=12)  
clf_2.fit(X_train_2, y_train_2)
y_pred_2 = clf_2.predict(X_test_2)
print("ACCURACY OF THE MODEL 2:", metrics.accuracy_score(y_test_2, y_pred_2))

clf_3 = RandomForestClassifier(n_estimators = 130,max_features=41,random_state=12)  
clf_3.fit(X_train_3, y_train_3)
y_pred_3 = clf_3.predict(X_test_3)
print("ACCURACY OF THE MODEL 3:", metrics.accuracy_score(y_test_3, y_pred_3))
# Train the model 38 features

clf_4 = RandomForestClassifier(n_estimators = 130,max_features=41,random_state=12)  
clf_4.fit(X_train_4, y_train_4)
y_pred_4 = clf_4.predict(X_test_4)
print("ACCURACY OF THE MODEL 4:", metrics.accuracy_score(y_test_4, y_pred_4))
# KNN classifier with 10 neightbors, witch is the optimal after some test
# Train the model 39 features

knn1 = KNeighborsClassifier(n_neighbors=10)
knn1.fit(X_train_1, y_train_1)
pred = knn1.predict(X_test_1)
print("ACCURACY OF THE MODEL KNN 1:", metrics.accuracy_score(y_test_1, pred))
# Train the model 39 features

knn2 = KNeighborsClassifier(n_neighbors=10)
knn2.fit(X_train_2, y_train_2)
pred = knn2.predict(X_test_2)
print("ACCURACY OF THE MODEL 2:", metrics.accuracy_score(y_test_2, pred))
# Train the model 40 features

knn3 = KNeighborsClassifier(n_neighbors=10)
knn3.fit(X_train_3, y_train_3)
pred = knn3.predict(X_test_3)
print("ACCURACY OF THE MODEL3:", metrics.accuracy_score(y_test_3, pred))
# Train the model 38 features

knn4 = KNeighborsClassifier(n_neighbors=10)
knn4.fit(X_train_4, y_train_4)
pred = knn4.predict(X_test_4)
print("ACCURACY OF THE MODEL 4:", metrics.accuracy_score(y_test_4, pred))
# Out:
# ACCURACY OF THE MODEL RF 1: 0.9166666666666666
# ACCURACY OF THE MODEL 2: 0.85
# ACCURACY OF THE MODEL 3: 0.7666666666666667
# ACCURACY OF THE MODEL 4: 0.95
# ACCURACY OF THE MODEL KNN 1: 0.9333333333333333
# ACCURACY OF THE MODEL 2: 0.8666666666666667
# ACCURACY OF THE MODEL3: 0.6666666666666666
# ACCURACY OF THE MODEL 4: 0.9166666666666666

# %% [markdown]
#  ## Linear Regrassion

# %%
#we laod the data again to prevent any collision of the data
import pandas as pd
import numpy as np
from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

#First we proccesing our data
import pandas as pd
#import the data from the csv file
df = pd.read_csv("student-mat.csv")
df = pd.DataFrame(df)
#modify the colunms yes->1 and no->0, because all the algorithms in data mining we will use can proccess data in string format
#we must have integers or floats, in our case we have one hot encoding and 0 or 1 for the 'yes' or 'no' features
for i in range(0, 395):
    if df.loc[i, "sex"] == 'F':
        df.loc[i, "sex"] = 0
    else:
        df.loc[i, "sex"] = 1
    if df.loc[i, "school"] ==  'GP':
        df.loc[i, "school"] = 0
    else:
        df.loc[i, "school"] = 1
    if df.loc[i, "romantic"] == 'no':
        df.loc[i, "romantic"] = 0
    else:
        df.loc[i, "romantic"] = 1

    if df.loc[i, "schoolsup"] == 'no':
        df.loc[i, "schoolsup"] = 0
    else:
        df.loc[i, "schoolsup"] = 1
        
    if df.loc[i, "famsup"] == 'no':
        df.loc[i, "famsup"] = 0
    else:
        df.loc[i, "famsup"] = 1
        
    if df.loc[i, "activities"] == 'no':
        df.loc[i, "activities"] = 0
    else:
        df.loc[i, "activities"] = 1
        
    if df.loc[i, "nursery"] == 'no':
        df.loc[i, "nursery"] = 0
    else:
        df.loc[i, "nursery"] = 1
        
    if df.loc[i, "higher"] == 'no':
        df.loc[i, "higher"] = 0
    else:
        df.loc[i, "higher"] = 1
        
    if df.loc[i, "internet"] == 'no':
        df.loc[i, "internet"] = 0
    else:
        df.loc[i, "internet"] = 1
    if df.loc[i, "paid"] == 'no':
        df.loc[i, "paid"] = 0
    else:
        df.loc[i, "paid"] = 1
    if df.loc[i, "address"] == 'U':
        df.loc[i, "address"] = 0
    else:
        df.loc[i, "address"] = 1
    if df.loc[i, "famsize"] == 'GT3':
        df.loc[i, "famsize"] = 0
    else:
        df.loc[i, "famsize"] = 1
        
    if df.loc[i, "Pstatus"] == 'A':
        df.loc[i, "Pstatus"] = 0
    else:
        df.loc[i, "Pstatus"] = 1


#also one hot encoding at the colunms
df = df.drop(['guardian'], axis=1)
one_hot_encoded = pd.get_dummies(df, dtype=int, columns=['Fjob', 'Mjob','reason'])
df = one_hot_encoded
#put the median of the  Medu and Fedu and Dalc and Walc
mean_Medu = df['Medu'].mean()
mean_Fedu = df['Fedu'].mean()

# Calculate the median
median = (mean_Medu + mean_Fedu) / 2

df = df.drop(['Fedu'], axis=1)
df.rename(columns={'Medu': 'Parents_edu'}, inplace=True)

# Replace all values in the renamed column
df['Parents_edu'] = df['Parents_edu'].replace(median)



mean_Medu = df['Dalc'].mean()
mean_Fedu = df['Walc'].mean()

# Calculate the median
median = (mean_Medu + mean_Fedu) / 2

df = df.drop(['Dalc'], axis=1)
df.rename(columns={'Walc': 'Dalc_Walc_median'}, inplace=True)

# Replace all values in the renamed column
df['Dalc_Walc_median'] = df['Dalc_Walc_median'].replace(median)
                                                        
scaler = StandardScaler()

scaler.fit(df.drop('G3', axis=1))
scaled_features = scaler.transform(df.drop('G3',
                                           axis=1))
df_feat = pd.DataFrame(scaled_features,
                       columns=df.columns[:-1])

X_train, X_test,\
    y_train, y_test = train_test_split(df_feat,
                                       df['G3'],
                                       test_size=0.15,random_state=12)



# Create a linear regression model
#the 40 feature scaler and model

model_regrassion = LinearRegression()

# Train the model
model_regrassion.fit(X_train, y_train)
# Make predictions on the test set
y_predicted = model_regrassion.predict(X_test)
yp = pd.DataFrame(y_predicted)
yt = pd.DataFrame(y_train)


# Calculate mean squared error (MSE) on the test set (optional)
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_predicted)
print("Mean Squared Error:", mse)
###################################
##################################
#the 39 feature scaler and model

scaler1 = StandardScaler()
df1 = df.drop('G1', axis=1)
scaler1.fit(df1.drop('G3', axis=1))
scaled_features1 = scaler1.transform(df1.drop('G3',
                                           axis=1))
df_feat1 = pd.DataFrame(scaled_features1,
                       columns=df1.columns[:-1])

X_train1, X_test1,\
    y_train1, y_test1 = train_test_split(df_feat1,
                                       df['G3'],
                                       test_size=0.15,random_state=12)

# Split data into training and testing sets
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)  # 20% for testing

# Create a linear regression model
model_regrassion1 = LinearRegression()

# Train the model
model_regrassion1.fit(X_train1, y_train1)
# Make predictions on the test set
y_predicted1 = model_regrassion1.predict(X_test1)
yp1 = pd.DataFrame(y_predicted1)
yt1 = pd.DataFrame(y_train1)
mse = mean_squared_error(y_test1, y_predicted1)
print("Mean Squared Error:", mse)
###################################
##################################
#the 39 feature scaler and model

scaler2 = StandardScaler()
df2 = df.drop('G2', axis=1)
scaler2.fit(df2.drop('G3', axis=1))
scaled_features2 = scaler2.transform(df2.drop('G3',
                                           axis=1))
df_feat2 = pd.DataFrame(scaled_features2,
                       columns=df2.columns[:-1])

X_train2, X_test2,\
    y_train2, y_test2 = train_test_split(df_feat2,
                                       df['G3'],
                                       test_size=0.15,random_state=12)


# Create a linear regression model
model_regrassion2 = LinearRegression()

# Train the model
model_regrassion2.fit(X_train2, y_train2)
# Make predictions on the test set
y_predicted2 = model_regrassion2.predict(X_test2)
yp2 = pd.DataFrame(y_predicted2)
yt2 = pd.DataFrame(y_train2)
mse = mean_squared_error(y_test2, y_predicted2)
print("Mean Squared Error:", mse)
###################################
##################################
#the 38 feature scaler and model
scaler3 = StandardScaler()
df3 = df.drop(['G2','G1'], axis=1)

scaler3.fit(df3.drop('G3', axis=1))
scaled_features3 = scaler3.transform(df3.drop('G3',
                                           axis=1))
df_feat3 = pd.DataFrame(scaled_features3,
                       columns=df3.columns[:-1])

X_train3, X_test3,\
    y_train3, y_test3 = train_test_split(df_feat3,
                                       df['G3'],
                                       test_size=0.15,random_state=12)



# Create a linear regression model
model_regrassion3 = LinearRegression()

# Train the model
model_regrassion3.fit(X_train3, y_train3)
# Make predictions on the test set
y_predicted3 = model_regrassion3.predict(X_test3)
yp3 = pd.DataFrame(y_predicted3)
yt3 = pd.DataFrame(y_train3)
mse = mean_squared_error(y_test3, y_predicted3)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 5.499707580225637
# Mean Squared Error: 5.435771313555303
# Mean Squared Error: 9.077960961057506
# Mean Squared Error: 18.950634280383618
# C:\Users\kater\AppData\Local\Temp\ipykernel_24388\2033413539.py:94: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['Parents_edu'] = df['Parents_edu'].replace(median)
# C:\Users\kater\AppData\Local\Temp\ipykernel_24388\2033413539.py:108: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['Dalc_Walc_median'] = df['Dalc_Walc_median'].replace(median)

# %% [markdown]
# ## Classifiers for classified the data into 5 classes:
# ## 1-10 , 10-12, 12-14, 14-16, 16-20

# %%
## take the data one more time
df = pd.read_csv("student-mat.csv")
df = pd.DataFrame(df)
#modify the colunms yes->1 and no->0
for i in range(0, 395):
    if df.loc[i, "sex"] == 'F':
        df.loc[i, "sex"] = 0
    else:
        df.loc[i, "sex"] = 1
    if df.loc[i, "school"] ==  'GP':
        df.loc[i, "school"] = 0
    else:
        df.loc[i, "school"] = 1
    if df.loc[i, "romantic"] == 'no':
        df.loc[i, "romantic"] = 0
    else:
        df.loc[i, "romantic"] = 1

    if df.loc[i, "schoolsup"] == 'no':
        df.loc[i, "schoolsup"] = 0
    else:
        df.loc[i, "schoolsup"] = 1
        
    if df.loc[i, "famsup"] == 'no':
        df.loc[i, "famsup"] = 0
    else:
        df.loc[i, "famsup"] = 1
        
    if df.loc[i, "activities"] == 'no':
        df.loc[i, "activities"] = 0
    else:
        df.loc[i, "activities"] = 1
        
    if df.loc[i, "nursery"] == 'no':
        df.loc[i, "nursery"] = 0
    else:
        df.loc[i, "nursery"] = 1
        
    if df.loc[i, "higher"] == 'no':
        df.loc[i, "higher"] = 0
    else:
        df.loc[i, "higher"] = 1
        

        
    if df.loc[i, "internet"] == 'no':
        df.loc[i, "internet"] = 0
    else:
        df.loc[i, "internet"] = 1
    if df.loc[i, "paid"] == 'no':
        df.loc[i, "paid"] = 0
    else:
        df.loc[i, "paid"] = 1
    if df.loc[i, "address"] == 'U':
        df.loc[i, "address"] = 0
    else:
        df.loc[i, "address"] = 1
    if df.loc[i, "famsize"] == 'GT3':
        df.loc[i, "famsize"] = 0
    else:
        df.loc[i, "famsize"] = 1
        
    if df.loc[i, "Pstatus"] == 'A':
        df.loc[i, "Pstatus"] = 0
    else:
        df.loc[i, "Pstatus"] = 1

    if df.loc[i, "G3"] <= 9:
        df.loc[i, "G3"] = 1
    if (df.loc[i, "G3"] >= 10 and df.loc[i, "G3"] < 12):
        df.loc[i, "G3"] = -1
    if (df.loc[i, "G3"] >= 12 and df.loc[i, "G3"] < 14):
        df.loc[i, "G3"] = 2
    if (df.loc[i, "G3"] >= 12 and df.loc[i, "G3"] < 16):
        df.loc[i, "G3"] = -2
    if df.loc[i, "G3"] >= 16:
        df.loc[i, "G3"] = 0
df = df.drop(['guardian'], axis=1)
one_hot_encoded = pd.get_dummies(df, dtype=int, columns=['Fjob', 'Mjob','reason'])
df = one_hot_encoded


#put the median of the  Medu and Fedu and Dalc and Walc
mean_Medu = df['Medu'].mean()
mean_Fedu = df['Fedu'].mean()

# Calculate the median
median = (mean_Medu + mean_Fedu) / 2

print("Median:", median)
df = df.drop(['Fedu'], axis=1)
df.rename(columns={'Medu': 'Parents_edu'}, inplace=True)

# Replace all values in the renamed column
df['Parents_edu'] = df['Parents_edu'].replace(median)



mean_Medu = df['Dalc'].mean()
mean_Fedu = df['Walc'].mean()

# Calculate the median
median = (mean_Medu + mean_Fedu) / 2

print("Median:", median)
df = df.drop(['Dalc'], axis=1)
df.rename(columns={'Walc': 'Dalc_Walc_median'}, inplace=True)

# Replace all values in the renamed column
df['Dalc_Walc_median'] = df['Dalc_Walc_median'].replace(median)


df_1 = df.drop(['G1'], axis=1)
df_2 = df.drop(['G2'], axis=1)
df_3 = df.drop(['G1','G2'], axis=1)
df_4 = df
from sklearn import metrics  
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report,\
    confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

from sklearn import metrics  
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import classification_report,\
    confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier


features_1 = df_1.drop('G3',axis=1)

X_train_11, X_test_11,\
    y_train_11, y_test_11 = train_test_split(features_1,
                                       df['G3'], test_size=0.15,random_state=42)


features = df_2.drop('G3',axis=1)
 
df_feat = pd.DataFrame(features,
                       columns=df.columns[:-1])
X_train_22, X_test_22,\
    y_train_22, y_test_22 = train_test_split(features,
                                       df['G3'],
                                       test_size=0.15,random_state=42)

features = df_3.drop('G3',axis=1)
 

X_train_33, X_test_33,\
    y_train_33, y_test_33 = train_test_split(features,
                                       df['G3'],
                                       test_size=0.15,random_state=42)


features = df_4.drop('G3',axis=1)
 
X_train_44, X_test_44,\
    y_train_44, y_test_44 = train_test_split(features,
                                       df['G3'],
                                       test_size=0.15,random_state=42)
#TRAIN THE NB MODELS
model_11 = GaussianNB()
model_11.fit(X_train_11, y_train_11)
y_pred = model_11.predict(X_test_11)
print("ACCURACY OF THE MODEL NB1:",metrics.accuracy_score(y_test_11, y_pred))

model_22 = GaussianNB()
model_22.fit(X_train_22, y_train_22)
y_pred = model_22.predict(X_test_22)
print("ACCURACY OF THE MODEL NB2:",metrics.accuracy_score(y_test_22, y_pred))

model_33 = GaussianNB()
model_33.fit(X_train_33, y_train_33)
y_pred = model_33.predict(X_test_33)
print("ACCURACY OF THE MODEL NB3:",metrics.accuracy_score(y_test_33, y_pred))

model_44 = GaussianNB()
model_44.fit(X_train_44, y_train_44)
y_pred = model_44.predict(X_test_44)
print("ACCURACY OF THE MODEL NB4:",metrics.accuracy_score(y_test_44, y_pred))

#TRAIN THE RF MODELS

clf_11 = RandomForestClassifier(n_estimators = 130,max_features=41,random_state=13)  
clf_11.fit(X_train_11, y_train_11)
y_pred_11 = clf_11.predict(X_test_11)
print("ACCURACY OF THE MODEL RF1:", metrics.accuracy_score(y_test_11, y_pred_11))

clf_22 = RandomForestClassifier(n_estimators = 130,max_features=41,random_state=12)  
clf_22.fit(X_train_22, y_train_22)
y_pred_22 = clf_22.predict(X_test_22)
print("ACCURACY OF THE MODEL RF2:", metrics.accuracy_score(y_test_22, y_pred_22))

clf_33 = RandomForestClassifier(n_estimators = 130,max_features=41,random_state=12)  
clf_33.fit(X_train_33, y_train_33)
y_pred_33 = clf_33.predict(X_test_33)
print("ACCURACY OF THE MODEL RF3:", metrics.accuracy_score(y_test_33, y_pred_33))

clf_44 = RandomForestClassifier(n_estimators = 225,max_features=41,random_state=89)  
clf_44.fit(X_train_44, y_train_44)
y_pred_44 = clf_44.predict(X_test_44)


print("ACCURACY OF THE MODEL RF4:", metrics.accuracy_score(y_test_44, y_pred_44))



#TRAIN THE KNN MODELS

knn11 = KNeighborsClassifier(n_neighbors=10)
knn11.fit(X_train_11, y_train_11)
pred = knn11.predict(X_test_11)
print("ACCURACY OF THE MODEL KNN:", metrics.accuracy_score(y_test_11, pred))
knn22 = KNeighborsClassifier(n_neighbors=10)
knn22.fit(X_train_22, y_train_22)
pred = knn22.predict(X_test_22)
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test_22, pred))
knn33 = KNeighborsClassifier(n_neighbors=10)
knn33.fit(X_train_33, y_train_33)
pred = knn33.predict(X_test_33)
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test_33, pred))
knn44 = KNeighborsClassifier(n_neighbors=10)
knn44.fit(X_train_44, y_train_44)
pred = knn44.predict(X_test_44)
print("ACCURACY OF THE MODEL:", metrics.accuracy_score(y_test_44, pred))
# Out:
# Median: 2.6354430379746834
# Median: 1.8860759493670887
# ACCURACY OF THE MODEL NB1: 0.6
# ACCURACY OF THE MODEL NB2: 0.48333333333333334
# ACCURACY OF THE MODEL NB3: 0.35
# ACCURACY OF THE MODEL NB4: 0.65
# C:\Users\kater\AppData\Local\Temp\ipykernel_24388\1452020210.py:95: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['Parents_edu'] = df['Parents_edu'].replace(median)
# C:\Users\kater\AppData\Local\Temp\ipykernel_24388\1452020210.py:110: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['Dalc_Walc_median'] = df['Dalc_Walc_median'].replace(median)
# ACCURACY OF THE MODEL RF1: 0.7666666666666667
# ACCURACY OF THE MODEL RF2: 0.6166666666666667
# ACCURACY OF THE MODEL RF3: 0.45
# ...

# %%
from tkinter import *
import numpy as np
## these function has the same functionality, to put the input data to a temp_array
def append_vars_1(var_school,var_sex,var_age,var_addr,var_Fsize,
                   var_Pstat,var_Pedu,var_traveltime,var_studytime,
             var_failures,var_schoolsup,
             var_famsup,var_paid,var_activities,
             var_nursery,var_higher): 
    array.append(var_school)
    array.append(var_sex)
    array.append(var_age)
    array.append(var_addr)
    array.append(var_Fsize)
    array.append(var_Pstat)
    array.append(var_Pedu+1)
    array.append(var_traveltime+1)
    array.append(var_studytime+1)
    array.append(var_failures)
    array.append(var_schoolsup)
    array.append(var_famsup)
    array.append(var_paid)
    array.append(var_activities)
    array.append(var_nursery)
    array.append(var_higher)

def append_vars_2(var_internet, var_romantic, var_famrel, var_freetime,var_goout,
                   var_Walc, var_health,
                   var_absences, var_motherJ, var_fatherJ,var_reason,g1,g2): 

    array.append(var_internet)
    array.append(var_romantic)
    array.append(var_famrel+1)
    array.append(var_freetime+1)
    array.append(var_goout+1)
    array.append(var_Walc+1)
    array.append(var_health+1)
    array.append(var_absences+1)

    if(g1 == ""):
        array.append(0)
    else: 
        array.append(float(g1))

    if(g2 == ""):
        array.append(0)
    else:
        array.append(float(g2))
    array.append(var_motherJ)
    array.append(var_fatherJ)
    array.append(var_reason)

#function that takes the input and puts them in a np.array also this function returns a array with
#40 features non is missing    
def data_collection_func():
    data_collection = np.zeros((1, 40))


    
    data_collection[0][0] = array[0]
    data_collection[0][1] = array[1]
    data_collection[0][2] = array[2] + 15#age
    for i in range(3,26):
        data_collection[0][i] = array[i]
    
    #one hot encoding
    if array[26] == 0:
        data_collection[0][26] = 1.0
    elif array[26] == 2:
        data_collection[0][27] = 1.0
    elif array[26] == 3:
        data_collection[0][28] = 1.0
    elif array[26] == 4:
        data_collection[0][29] = 1.0
    elif array[26] == 4:
        data_collection[0][30] = 1.0
    
    if array[27] == 0:
        data_collection[0][31] = 1.0
    elif array[27] == 0:
        data_collection[0][32] = 1.0
    elif array[27] == 1:
        data_collection[0][33] = 1.0
    elif array[27] == 2:
        data_collection[0][34] = 1.0
    elif array[27] == 4:
        data_collection[0][35] = 1.0
        
    if array[28] == 0:
        data_collection[0][36] = 1.0    
    elif array[28] == 0:
        data_collection[0][37] = 1.0
    elif array[28] == 1:
        data_collection[0][38] = 1.0
    elif array[28] == 2:
        data_collection[0][39] = 1.0
        
    return data_collection
#function that takes the input and puts them in a np.array also this function returns a array with
#39 features
def data_collection_func_without_one_Grade():
    data_collection = np.zeros((1, 39))

    # Assuming 'array' is defined somewhere in your code
    # Replace 'array' with your actual array variable name
    
    data_collection[0][0] = array[0]
    data_collection[0][1] = array[1]
    data_collection[0][2] = array[2] + 15#age
    
    for i in range(3,25):
        data_collection[0][i] = array[i]
    #one hot encoding
    if array[25] == 0:
        data_collection[0][25] = 1.0
    elif array[25] == 1:
        data_collection[0][26] = 1.0
    elif array[25] == 2:
        data_collection[0][27] = 1.0
    elif array[25] == 3:
        data_collection[0][28] = 1.0
    elif array[25] == 4:
        data_collection[0][29] = 1.0
    
    if array[26] == 0:
        data_collection[0][30] = 1.0
    elif array[26] == 1:
        data_collection[0][31] = 1.0
    elif array[26] == 2:
        data_collection[0][32] = 1.0
    elif array[26] == 3:
        data_collection[0][33] = 1.0
    elif array[26] == 4:
        data_collection[0][34] = 1.0
    
    if array[27] == 0:
        data_collection[0][35] = 1.0
    elif array[27] == 1:
        data_collection[0][36] = 1.0
    elif array[27] == 2:
        data_collection[0][37] = 1.0
    elif array[27] == 3:
        data_collection[0][38] = 1.0
        
    return data_collection
#function that takes the input and puts them in a np.array also this function returns a array with
#38 features
def data_collection_func_without_two_Grade():
    data_collection = np.zeros((1, 38))
    
    data_collection[0][0] = array[0]
    data_collection[0][1] = array[1]
    data_collection[0][2] = array[2] + 15#age
    
    for i in range(3,24):
        data_collection[0][i] = array[i]
    #one hot encoding
    if array[26] == 0:
        data_collection[0][24] = 1.0
    elif array[26] == 1:
        data_collection[0][25] = 1.0
    elif array[26] == 2:
        data_collection[0][26] = 1.0
    elif array[26] == 3:
        data_collection[0][27] = 1.0
    elif array[26] == 4:
        data_collection[0][28] = 1.0
    
    if array[27] == 0:
        data_collection[0][29] = 1.0
    elif array[27] == 1:
        data_collection[0][30] = 1.0
    elif array[27] == 2:
        data_collection[0][31] = 1.0
    elif array[27] == 3:
        data_collection[0][32] = 1.0
    elif array[27] == 4:
        data_collection[0][33] = 1.0
    
    if array[28] == 0:
        data_collection[0][34] = 1.0
    elif array[28] == 1:
        data_collection[0][35] = 1.0
    elif array[28] == 2:
        data_collection[0][36] = 1.0
    elif array[28] == 3:
        data_collection[0][37] = 1.0
        
    return data_collection
    
# Function to create a set of horizontal radio buttons
def create_horizontal_radio_buttons(master, label_text, options, var):
    frame = Frame(master, bg="skyblue")
    frame.pack(pady=5)
    label = Label(frame, text=label_text, font=("Times", 12), bg="skyblue")
    label.pack(side="left", padx=5)
    for value, text in enumerate(options):
        rb = Radiobutton(frame, text=text, value=value, variable=var, bg="skyblue")
        rb.pack(side="left")
#Binary classifier
def make_Binary_classification(window3):
    window3.destroy()
    data = data_collection_func()
    #classier depend on the number of features 38,39 or 40 if the G1 and G2 missing or not
    if(data[0][24] == 0 and data[0][25] != 0):
        data = data_collection_func_without_one_Grade()
        res = knn1.predict(data)
        
    elif(data[0][24] != 0 and data[0][25] == 0):
        data = data_collection_func_without_one_Grade()
        res = clf_2.predict(data)
        
    elif(data[0][24] == 0 and data[0][25] == 0):
        data = data_collection_func_without_two_Grade()
        res = model_3.predict(data)
    elif(data[0][24] != 0 and data[0][25] != 0):
        res = clf_4.predict(data)  
        
    window4 = Tk()
    window4.geometry("600x90")
    #create the right window and display the a label depend on the res(result) of the classifier
    # res = 1 :pass
    # res = 0 :fail
    if(res == 1):
        window4.configure(background="green")
        window4.title("You Pass")
        L = Label(window4, text="Your final grade is above 10! Nice Job!", font=("Times", 18), bg="green").pack()

    else:
        window4.configure(background="red")
        window4.title("You Fail")
        L = Label(window4, text="Your final grade is below 10.You should give more effort",font=("Times", 18), bg="red").pack()

#Regression
def make_regression(window3):
    window3.destroy()
    data = data_collection_func()
    
    #G2 and G1 was given so we make a prediction
    if(data[0][24] != 0 and data[0][25] != 0):
        
        data = data_collection_func()
        data_collection = data.astype(np.float64)
        #scale the data before the prediction
        scaled_features = scaler.transform(data_collection)
        res = model_regrassion.predict(scaled_features)
        window4 = Tk()
        window4.geometry("600x90")
        window4.configure(background="skyblue")
        window4.title("ERROR")
        L = Label(window4, text=f"Your grade is {res}", font=("Times", 18), bg="skyblue").pack()


    #G2 and/or G1 was not given, error we can't predict a final grade  
    else:
        window4 = Tk()
        window4.geometry("600x90")
        window4.configure(background="red")
        window4.title("ERROR")
        L = Label(window4, text="Please enter at least one Grade!", font=("Times", 18), bg="red").pack()
     




def make_classification_5_class(window3):
    window3.destroy()
    data = data_collection_func()
    #classier depend on the number of features 38,39 or 40 if the G1 and G2 missing or not
    if(data[0][24] == 0 and data[0][25] != 0):
        data = data_collection_func_without_one_Grade()
        res = clf_11.predict(data)
        
    elif(data[0][24] != 0 and data[0][25] == 0):
        data = data_collection_func_without_one_Grade()
        res = clf_22.predict(data)
        
    elif(data[0][24] == 0 and data[0][25] == 0):
        data = data_collection_func_without_two_Grade()
        res = model_33.predict(data)
    elif(data[0][24] != 0 and data[0][25] != 0):
        res = clf_44.predict(data)  
    #create a window
    window4 = Tk()
    window4.geometry("600x90")
    #create the right window and display the a label depend on the res(result) of the classifier
    #1rs class
    if(res == 1):
        window4.configure(background="red")
        window4.title("You Fail")
        L = Label(window4, text="Your final grade is between 0 and 9! You have to try more!", font=("Times", 18), bg="red").pack()
    #2nd class
    if(res == -1):
        window4.configure(background="yellow")
        window4.title("You Pass")
        L = Label(window4, text="Your final grade is between 10 and 12!", font=("Times", 18), bg="yellow").pack()
    #3rd class
    if(res == -2):
        window4.configure(background="pink")
        window4.title("You Pass")
        L = Label(window4, text="Your final grade is between 12 and 14!", font=("Times", 18), bg="pink").pack()
    #4th place
    if(res == 0):
        window4.configure(background="green")
        window4.title("You Pass")
        L = Label(window4, text="Your final grade is between 16 and 20! Nice Job!", font=("Times", 18), bg="green").pack()
    #5th class
    if(res == 2):
        window4.configure(background="lightblue")
        window4.title("You Pass")
        L = Label(window4, text="Your final grade is between 14 and 16! Nice Job!", font=("Times", 18), bg="lightblue").pack()


def open(window2):
    #create the next window
    window2.destroy()
    window3 = Tk()
    window3.geometry("1400x1000")
    window3.configure(background="skyblue")
    window3.title("Classification App")
                  
    #some variables for the input , all double type 
    var_internet = DoubleVar()
    var_romantic = DoubleVar()
    var_famrel = DoubleVar()
    var_freetime = DoubleVar()
    var_goout = DoubleVar()
    var_Dalc = DoubleVar()
    var_Walc = DoubleVar()
    var_health = DoubleVar()
    var_absences = DoubleVar()
    var_mohterJ= DoubleVar()
    var_fatherJ= DoubleVar()
    var_reason= DoubleVar()
    G1_entry= DoubleVar()
    G2_entry= DoubleVar()

    # Create horizontal radio buttons for each input
    create_horizontal_radio_buttons(window3, "Internet Access at Home:", ["No", "Yes"], var_internet)
    create_horizontal_radio_buttons(window3, "Romantic Relationship:", ["No", "Yes"], var_romantic)
    create_horizontal_radio_buttons(window3, "Family Relationships Quality:", ["Very Bad", "Bad", "Neutral", "Good", "Excellent"], var_famrel)
    create_horizontal_radio_buttons(window3, "Free Time after School:", ["Very Low", "Low", "Medium", "High", "Very High"], var_freetime)
    create_horizontal_radio_buttons(window3, "Going Out with Friends:", ["Very Low", "Low", "Medium", "High", "Very High"], var_goout)
    create_horizontal_radio_buttons(window3, "Week Alcohol Consumption:", ["Very Low", "Low", "Medium", "High", "Very High"], var_Walc)
    create_horizontal_radio_buttons(window3, "Current Health Status:", ["Very Bad", "Bad", "Neutral", "Good", "Very Good"], var_health)
    create_horizontal_radio_buttons(window3, "Number of School Absences:", ["0", "1-10", "11-20", "21-30", "More than 30"], var_absences)
    create_horizontal_radio_buttons(window3, "Mother's Job:", ["At Home", "Health Care Related", "Other","Civil Services","Teacher"], var_mohterJ)
    create_horizontal_radio_buttons(window3, "Father's Job:", ["At Home" ,"Health Care Related","Other","Civil Services","Teacher"], var_fatherJ)
    create_horizontal_radio_buttons(window3, "Reason to Choose School:", ["Course Preference","Close to Home", "Other", "School Reputation"], var_reason)
    #entry and label for the G1 and G2 input
    G1_entry_label = Label(window3, text="Enter your grade in the first term (optional)")
    G1_entry_label.configure(background="skyblue")
    G1_entry_label.pack()
    G1_entry = Entry(window3)
    G1_entry.pack()

    G2_entry_label = Label(window3, text="Enter your grade in the second term (optional)")
    G2_entry_label.configure(background="skyblue")
    G2_entry_label.pack()
    G2_entry = Entry(window3)
    G2_entry.pack()
    label_prediction_choice = Label(window3, text=" Choose your type of prediction:", font=("Arial", 20), bg="skyblue").pack()
    label_empty = Label(window3, text=" ", font=("Times", 12), bg="skyblue").pack()

    #make some buttons for classifier and regression
    bottomframe = Frame(window3)
    bottomframe.pack()
    frame = Frame(window3)
    frame.pack()
    
    #create some buttons
    button_5_classifier = Button(frame, text="Results Exams: Predict the group of Grade ", 
                                 command= lambda: make_classification_5_class(window3), 
                                 font=("Arial", 15), bg="white").pack(side=LEFT)

    bbutton3 = Button(bottomframe, text="Submit",
                      command= lambda: append_vars_2(var_internet.get(),
                                                    var_romantic.get(),var_famrel.get(),var_freetime.get(),
                                                    var_goout.get(),var_Walc.get(),var_health.get(),var_absences.get(),
                                                    var_mohterJ.get(),var_fatherJ.get(),var_reason.get(),
                                                     G1_entry.get(),G2_entry.get()),
                        font=("Arial", 15), bg="white").pack(side=TOP)
    
    button_Pass_fail = Button(frame, text="Results Exams: Pass or Fail", command= lambda: make_Binary_classification(window3), font=("Arial", 15), bg="white").pack(side=LEFT)
    button_Regression = Button(frame, text="Results Exams: Predict Exact Grade", command= lambda: make_regression(window3),  font=("Arial", 15), bg="white").pack(side=LEFT)

    
    
    
#main#

#main window
window1 = Tk()

#some variables for the input , all double type 
var_school = DoubleVar()
var_sex = DoubleVar()
var_age = DoubleVar()
var_addr = DoubleVar()
var_Fsize = DoubleVar()
var_Pstat = DoubleVar()
var_Pedu = DoubleVar()
var_traveltime = DoubleVar()
var_studytime = DoubleVar()
var_failures = DoubleVar()
var_schoolsup = DoubleVar()
var_famsup = DoubleVar()
var_paid = DoubleVar()
var_activities = DoubleVar()
var_nursery = DoubleVar()
var_higher = DoubleVar()
#make the main window
window1.geometry("1200x900")
window1.configure(background="skyblue")
window1.title("Classification App")
#temporary array to store the input
array = []


# Create horizontal radio buttons for each input
create_horizontal_radio_buttons(window1, "School:", ["Gabriel Pereira", "Mousinho da Silveira"], var_school)
create_horizontal_radio_buttons(window1, "Sex:", ["Female", "Male"], var_sex)
create_horizontal_radio_buttons(window1, "Age:", ["15", "16", "17", "18", "19", "20", "21", "22"], var_age)
create_horizontal_radio_buttons(window1, "Address Type:", ["Urban", "Rural"], var_addr)
create_horizontal_radio_buttons(window1, "Family Size:", ["Less than or equal to 3", "Greater than 3"], var_Fsize)
create_horizontal_radio_buttons(window1, "Parent's Status:", ["Apart", "Living together"], var_Pstat)
create_horizontal_radio_buttons(window1, "Parent's Education:", ["None", "Primary Education", "5th to 9th Grade", "Secondary Education", "Higher Education"], var_Pedu)
create_horizontal_radio_buttons(window1, "Home to School Travel Time:", ["<15 min.", "15 to 30 min.", "30 min. to 1 hour", ">1 hour"], var_traveltime)
create_horizontal_radio_buttons(window1, "Weekly Study Time:", ["<2 hours", "2 to 5 hours", "5 to 10 hours", ">10 hours"], var_studytime)
create_horizontal_radio_buttons(window1, "Number of Past Class Failures:", ["<3", "4"], var_failures)
create_horizontal_radio_buttons(window1, "Extra Educational Support:", ["No", "Yes"], var_schoolsup)
create_horizontal_radio_buttons(window1, "Family Educational Support:", ["No", "Yes"], var_famsup)
create_horizontal_radio_buttons(window1, "Extra Paid Classes:", ["No", "Yes"], var_paid)
create_horizontal_radio_buttons(window1, "Extra-Curricular Activities:", ["No", "Yes"], var_activities)
create_horizontal_radio_buttons(window1, "Attended Nursery School:", ["No", "Yes"], var_nursery)
create_horizontal_radio_buttons(window1, "Desire for Higher Education:", ["No", "Yes"], var_higher)




#create some buttons
button_submit = Button(window1, text="Submit",
                       command= lambda: append_vars_1(var_school.get(),var_sex.get(),var_age.get(),
                                                var_addr.get(),var_Fsize.get(),var_Pstat.get(),
                                                var_Pedu.get(),var_traveltime.get(),var_studytime.get(),
                                                var_failures.get(),var_schoolsup.get(),
                                                var_famsup.get(),var_paid.get(),var_activities.get(),
                                                var_nursery.get(),var_higher.get()), font=("Arial", 15), bg="white").pack()

button_open = Button(window1, text="Continue", command= lambda: open(window1), font=("Arial", 15), bg="white").pack()


window1.mainloop()
# Out:
# C:\Users\kater\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
